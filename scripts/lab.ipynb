# %%
import pandas as pd 

df = pd.read_csv("../data/annotated_data/annotated_baljeet.csv")


df["Topic"].unique()


# # Clean up the \xa0 
# df["Category"] = df["Category"].str.replace("\xa0", " ").str.strip()

# # Convert all to lowercase
# df["Category"] = df["Category"].str.lower()

# # replace all instances of "?" with "Info dumping"
# df["Category"] = df["Category"].str.replace("?", "Info dumping")


# # find sum of dialogues with category "?"
# df["Category"].value_counts()

# grouped = df.groupby("Category")["Dialog"].apply(list)

# grouped["school"]
# Out:
# array([' time-travelling', ' time travelling', ' science', ' philosophy',
#        ' science / school', ' ///////////////', ' inventions',
#        ' Phineas & Ferb ', ' storytelling', ' school', ' info-dumping',
#        ' ////////////////', ' //////// maybe school', ' /////////////',
#        ' time travelling ', ' science ', ' invention',
#        ' ////////////////////', ' time-travelling ', ' inventions ',
#        ' Phineas & Ferb', nan], dtype=object)
