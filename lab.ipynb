# %%
import pandas as pd 


df = pd.read_csv("data/annotated_data/Book2.csv")

# Strip whitespace (including non-breaking spaces \xa0) and convert to lowercase
df['Category'] = df['Category'].str.strip().str.lower()

df["Category"].value_counts()
# Out:
# ?                133
# food              45
# relationships     40
# philosophy        32
# info dumping      23
# science           16
# p and f           12
# time travel        1
# school             1
# Name: Category, dtype: int64
