# %%
import pandas as pd 

df = pd.read_csv("../data/annotated_data/annotated_buford.csv")


df["Category"].unique()
# Out:
# /var/folders/h7/xk5qjr4n7951h6pvbhjmsq900000gn/T/ipykernel_43238/750968911.py:10: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Category"] = df["Category"].str.replace("?", "Info dumping")

# %%
# Clean up the \xa0 
df["Category"] = df["Category"].str.replace("\xa0", " ").str.strip()

# Convert all to lowercase
df["Category"] = df["Category"].str.lower()

# replace all instances of "?" with "Info dumping"
df["Category"] = df["Category"].str.replace("?", "Info dumping")


# find sum of dialogues with category "?"
df["Category"].value_counts()
# Out:
# /var/folders/h7/xk5qjr4n7951h6pvbhjmsq900000gn/T/ipykernel_43238/866165361.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Category"] = df["Category"].str.replace("?", "Info dumping")
# info dumping     151
# food              45
# relationships     41
# philosophy        32
# science           16
# p and f           12
# time travel        1
# school             1
# Name: Category, dtype: int64

# %%
grouped = df.groupby("Category")["Dialog"].apply(list)

grouped["school"]
# Out:
# ['Hey, the epic struggle of a triangle-headed boy to choose between two schools.']
