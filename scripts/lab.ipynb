# %%
import pandas as pd 

df = pd.read_csv("../data/annotated_data/annotated_candance.csv")


df["Annotation"].unique()


# # Clean up the \xa0 
# df["Category"] = df["Category"].str.replace("\xa0", " ").str.strip()

# # Convert all to lowercase
# df["Category"] = df["Category"].str.lower()

# # replace all instances of "?" with "Info dumping"
# df["Category"] = df["Category"].str.replace("?", "Info dumping")


# # find sum of dialogues with category "?"
# df["Category"].value_counts()



# grouped["school"]
# Out:
# array(['Phineas and Ferb', 'Philosophy', 'Relationships', 'Infodumping',
#        'Science / Inventions', 'School', 'Food'], dtype=object)

# %%
grouped = df.groupby("Annotation")["Dialog"].apply(list)

grouped["Science / Inventions"]
# Out:
# ["Okay, you guys are so... hey, they're not here. What's this? This stuff's way below their usually bustable level. I wonder what they're doing out here with Dad's old barbells. (Candace lifts barbells) Hey, I've never been able to... (gasps) Super strength. What if that really was a vampire bat? Candace, get a hold of yourself. I mean, it's not like I can fly. (Candace floats in air) Oh my gosh! Okay there's only one way to know for sure. A mirror. (Candace's reflection in the mirror disappears) Oh no, no reflection!",
# ...
