# %%
import pandas as pd 

df = pd.read_csv("../data/annotated_data/annotated_baljeet.csv")




# # Clean up the \xa0 
# df["Category"] = df["Category"].str.replace("\xa0", " ").str.strip()

# # Convert all to lowercase
# df["Category"] = df["Category"].str.lower()

# # replace all instances of "?" with "Info dumping"
# df["Category"] = df["Category"].str.replace("?", "Info dumping")


# # find sum of dialogues with category "?"
# df["Category"].value_counts()
# Strip whitespace from the 'Topic' column
df['Topic'] = df['Topic'].str.strip()

# Check the unique values again to verify
print(df['Topic'].unique())




# grouped["school"]
# Out:
# ['science' 'philosophy' 'school' 'relationships' 'Phineas & Ferb'
#  'info-dumping' 'food' nan]

# %%
grouped = df.groupby("Topic")["Dialog"].apply(list)

grouped["info-dumping"]
# Out:
# ['In 1903, my great-grandfather was leading a bicycle race, when he fell into a tiger pit. Years later, my grandfather skillfully avoided the tiger pit, but sadly not the tiger. Then, my father was confident he had outsmarted the tiger, but he was wrong.',
#  'I did. We Speckies vow to live in peace and harmony with you Finkies. All we ask is that you admit Space Adventure is much better than Stumbleberry Finkbat, and that you have brought eternal shame to your families forever believing otherwise.',
#  'Listen, here is how it works. By observing the swamp, logic tells me that it is too big to go around. And by gathering information about it from Isabel, I can logically make assessments about the best way to get across. Are you following me?',
#  "Actually, I can think of many things that I can not do. Flying comes to mind. Also putting my foot behind my head, but it occurs to me that you're speaking hyperbolically. So point taken, Greg LeMond! I'm going to win this race!",
#  'Because today is the Tri-State Area Unification Day! I learned all about it in Assimilation class. You see, the Tri-State Area was the bi-state area until our founder, the great John P. Trystate, uttered the immortal words:',
#  "W-what? Uh, uh, oh. Thank you. Well, this is a story about a kid who comes to this country, and goes to camp. He, like, has to share a tent with a bully. It's really quite terrifying, actually. Quite terrifying.",
#  "He is always giving us a hard time...He says he is our friend! Would a friend steal your bike?! To be fair, he stole everyone's bike...And what about the time he drank all the water out of our fish tank?!",
#  'Based on his extensive history of malapropisms, I would say that he is talking about the Chupacabra, the Latin American goat sucker, that is said to haunt the deserts of Mexico and South-Western America.',
#  'Useless Shoelace Facts, Volume 8. "The plastic or metal tip on the end of a shoelace is called an... aglet. A-G-L-E-T. It is one of the most useful, yet tragically ignored inventions in all of history".',
#  "Phineas and Ferb, days ago, you helped me build a portal to Mars. Now, I beg you to help me win the Biggest Watermelon Contest at the festival. Help me, Phineas and Ferb. You're my only hope!",
#  'So after hiding in the bathroom, I jumped out the window and came over here as quickly as possible. I do not even know how to act in front of a girl! I do not even know what girls like.',
#  'Buford! You\'re completely disrespecting this classic song. You\'re ignoring the historical context! King Wenceslas was a great man. You have no idea what this song is about!"',
#  'No can do, Phineas. I am taking an eastern Indian cooking class. We are going to make goat vindaloo. If we can ever find a goat. Oh! There is one now. Got to run!',
#  'No! I moved polka back so I could answer your question! It would take some major rearranging, but I think I can at least come to watch you make the bubble.',
#  'For your safety, Mishti, I invite you to hold on to the rail. It appears to be very clean, which I know is important to you now that you are a girl.',
#  'Well, folks, I do not know about Western cinema, but this Forced Perspective Western Town has been a hoot, which I am just now realizing is a thing.',
#  'I did it! I won a bike race! Thanks to Greg LeMond inspiring me. And then, you know, getting attacked by that tiger. By the way, I hope he is okay.',
#  'Yes! Yes, it does! This way my work will not be interrupted by creatures who cannot possibly understand it! Like raccoons, or people, for instance.',
#  "Not to add pressure to what is already a high-pressure system... but we have six minutes and forty-one seconds 'til your mom dissipates completely!",
#  "I said early. Anyway, under personal preferences, I could not decide whether to select 'Loop' or 'String' theory. I was paralyzed with indecision!",
#  'N-No! Of course not, sir. Hehe Here, sir. Try our deluxe peanut chicken. Our **motto** is: "So Peanutty, you will not even taste the chicken!"',
#  'That\'s because it is. Every minute of my entire day is planned out right here. Remember how you told me to seize the day? Consider it seized!"',
#  'Uh my schedule is extremely tight. I doubt I even have a second to answer your question. Maybe if I move my polka recital back. Okay.',
#  'Do not worry, Phineas. With all of her training, she will be fine. Just last week, she earned her Judo, Hapkido, and Jujitsu Patches.',
#  'I am not mechanically inclined like the two of you. To truly understand my predicament, I feel it will be best expressed in a song.',
#  'You know this is pretty tame compared to other roller coasters, but when you compare it to other dental themed rides, it is a rush!',
#  'I feel this may not be the best way to block a shot. Clearly I was - Clearly I was wrong about that. That was most effective. Aah!',
#  'Okay. Right... There! In fifteen seconds, that is the point of maximum disturbance! So it should be appearing right over...there!',
#  'While this Forced Perspective Town is charming, it has not changed my perspective. I still find the Western film genre tacky and—',
#  "Oh, that's it! I will become Hanuman Man, a flying blue monkey that can grow as massive as he desires to crush all in his way!",
#  'Um, hello? Can we discuss the bigger problem? And by "bigger problem", I mean "THE BERSERK NECROSLUG THAT IS ON THE LOOSE"!',
#  'It is like our own miniature Canada! But, of course, without the beavers, moose, and disproportionate number of comedians.',
#  "Last stop! I'm afraid there is no way to get to the East Coast by boat unless you go all the way around South America.",
#  'But how? Mr. Random is already miles away. We have no idea where he is going and no way to get there except on foot!',
#  'There is a new Space Adventure movie filming in Danville. The Namrak Necroslug. And I have been invited to audition!',
#  "We're going to the circus! We're going to the circus! I am here and ready to go to the world-famous Cirque de Lune.",
#  'And spoil my carefully calculated air of selfishness and unconcern? Not until the last second thank you very much!',
#  'Good, we will just wait here and eventually, the fuel will run out. Ohh... And then she will plummet to...yeah...',
#  'YES! I have BEAT you, Danville Mountain! In your cliff face! Ha ha! I cannot wait to tell Buf- oh. That is right.',
#  'Ah! this is catastrophic! Should we not do something? Should no one inform the populous of the impending impact?',
#  'This is great! Now that I have made both choices, I will no longer miss any opp- What do you know! I was right!',
#  'Huh. Usually, some unforeseen element would have removed our invention by now. Perhaps we should take it down.',
#  'No, no please! I have given my solemn oath to protect the little monotreme until the Flynn family comes home.',
#  'I can see how that would be relevant if we were going to eat it. We are not going to have to eat it, are we?!',
#  'I did not go through six years of ninja school just to be called Dr. Baljeet. It is Dr. Ninja Baljeet, okay?',
#  'Because, as a person of superior intellect, I require an angry wall of meat to protect my science project.',
#  'Shape-shifting alien zombies, fair enough, but I must tell you that I am kind of using my brain right now.',
#  'If we could just stick to the topic, please. Five minutes and forty-eight seconds ago, back in my home...',
#  "Well, without over-complicating things, it's a portal to Mars. You step through it and you're on Mars.",
#  'I was too excited to wait. I shaved last night. Just call me Bald-jeet. Heh-heh. Get it? "Bald-jeet"?',
#  'They are really into online gaming now! Hey, who cast a sleep spell on me and stole all my gold? Ugh!',
#  'Just follow the trajectory I plotted out and I promise you will hit the final target! We can do this!',
#  'Ah, there it is! The finish line, right on the other side of Danville Chasm. I am going to win this!',
#  'We may be doomed but these nimble fingers and five years of violin lessons can play us out in style.',
#  'This place is creeping me out. If I had any underpants left, I am sure they would have been soiled.',
#  'It is okay, Mrs Flynn-Fletcher, we were just talking about how easy it is to make a bad decision.',
#  'My time is limited, Magician. I must gather my positronic impulses for the coming battle. Speak.',
#  'I know! But it took me three minutes to remember how to give my self a CAT scan! I am slipping!',
#  'So, if you do not believe the flying saucer is real, why did you want to take a turn flying it?',
#  'Wow! The fact that we cannot open it makes discovering the contents that much more tantalizing!',
#  'Stop looking at me, I am not going to do jazz hands! Even though you have totally earned it...',
#  'Aghh! You can build a rollercoaster in a day, but it takes you 12 minutes to pump up a tire?!',
#  'Oh, but what about all those innocent baristas and bank tellers and bowling alley attendants?',
#  'This is great! With my stimulated brain, I am dreaming up all sorts of super smart projects!',
#  'It got me through hoof and mouth disease. And I have already downloaded my favorite episode.',
#  'Do not worry your pretty little head. I have plenty of experience with this sort of thing.',
#  'Do you find it as curious as I do that your menu has not changed since you opened in 1929?',
#  'Wow; I have no idea how to respond that. I think I will be continuing with the race now.',
#  'It seems too heavy for an airlift. Perhaps if we had two trucks attached side by side...',
#  'Oh no! I knew I should not have forsaken the rigid beauty of my candy-colored schedule!',
#  'How can I sit tight? With that air conditioner up there freezing me! So cold. So cold.',
#  'Huh. Did you say "Wind-Con"? The largest annual international wind-themed convention?!',
#  'I am watching Perry the Platypus. I promised to not take my eyes out off him all day.',
#  "Oh, here we go again. He's going to tell the story of when he was abducted by aliens.",
#  'If it is okay with you, I have prepared a little presentation to illustrate my point.',
#  'Hop on! The mole people startle easily. But they will be back and in greater numbers.',
#  'Oh, it is hopeless. I am never going to get my special mistletoe Christmas kiss. Ah!',
#  'Well, empirically speaking, the test results show almost unanimous approval ratings!',
#  '...we are in for a moderate cold front that shows absolutely no signs of subsiding."',
#  'And a little extra yeast in the baguette will increase our overall maneuverability.',
#  'This is usually the part of the day when pitch us building your bread bowl hot tub."',
#  'They appear to have been domesticated. They have no squirrel skills. Check it out.',
#  'Huh. Deception aside, my confidence is at an all-time high. Exterra fears nothing!',
#  'Only a few more seconds to my greatest triumph! I wonder what I will do tomorrow.',
#  'Oddly enough, I feel the same. But I am not worried about making choices anymore.',
#  'Due to unresolved contract negotiations, Stumbleberry Finkbat has been cancelled!',
#  'In a minute. So to continue, the figure eight and... Awwww, annnnnd we are back.',
#  'You know, I can see these vines are just painted ropes. How can I act with this?',
#  'Which part? The unicorn or Officer Concord the Juice Time Juice Box Flavor Cop?',
#  'Funny how things worked out so that everyone pretty much got what they wanted.',
#  'Okay, everyone! Here is how you play: You hold your top...and then...you SPIN!',
#  'Everyone, please stand back! Keep your fingers, and berets away from the bars.',
#  "Oh. I mean, it's, uh, it's totally gotten so commercialized now. It's so lame.",
#  'Where are you getting your information from, disembodied reggae space voice?',
#  'No gadgets, no gimmicks, just pure achievement! It will be great! Let us go!',
#  'I hope you have got your carry on stowed, because we are ready for take-off.',
#  'Oh, sweet. I am going down there. Okay, here I am. What have you got for me?',
#  'What you have found is a one-way magic carpet ride to your own destruction.',
#  'Haha! That gives me a five points weapon skills advantage. You lose an arm!',
#  'But if we do the mind swap here, those criminals will still be out of jail.',
#  "What mysteries does it contain? Perhaps dozens of stray Schrödinger's cats?",
#  "It is almost like Tadashi Kawamata's massive chair sculpture in Abu Dhabi.",
#  'Yes. All you need is the first part, and then you will have a whole joke.',
#  'Why is he wearing a tuxedo? It looks like he should be on a wedding cake.',
#  'And now, for your in-flight entertainment; The Paper Pelican Floor Show!']
